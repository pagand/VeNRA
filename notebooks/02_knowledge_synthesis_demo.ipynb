# %% [markdown]
# # Knowledge Synthesis Demo (Stage 2)
#
# This notebook demonstrates the transformation of the raw DOM (Stage 1) into the Universal Fact Ledger (UFL).
# It covers:
# 1. **Entity Resolution:** Identifying 'TransDigm' from the cover page.
# 2. **Table Melting:** Converting Markdown tables to structured UFLRows.
# 3. **Text Extraction:** Using Llama-3 via Instructor to extract facts from text.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import nest_asyncio

# Add src to path
sys.path.append(os.path.abspath("../src"))

from venra.ingestion import StructuralParser
from venra.synthesis import EntityResolver, TableMelter, TextSynthesizer
from venra.models import BlockType
from venra.logging_config import logger

nest_asyncio.apply()
# Out:
# /Users/pedram/Projects/VeNRA/.venv/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validate_default' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'validate_default' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %% [markdown]
# ## 1. Load Data (Stage 1 Output)

# %%
DOM_PATH = "../data/processed/10k_test_dom.pkl"
blocks = StructuralParser.load_dom(DOM_PATH)
print(f"Loaded {len(blocks)} blocks.")
# Out:
# Loaded 61 blocks.

# %% [markdown]
# ## 2. Entity Resolution

# %%
# Initialize Resolver
resolver = EntityResolver()

# Run Resolution (Simulated call to Groq if key is present)
entity_meta = await resolver.resolve_entity(blocks)
print(f"Canonical ID: {entity_meta.canonical_id}")
print(f"Official Name: {entity_meta.official_name}")
print(f"Aliases: {entity_meta.aliases}")
# Out:
# 2026-02-23 21:55:32,641 - venra - INFO - Resolving Entity from Cover Page context…
# 2026-02-23 21:55:33,461 - venra - INFO - Resolved Entity: ID_TDG (TransDigm Group Incorporated)
# Canonical ID: ID_TDG
# Official Name: TransDigm Group Incorporated
# Aliases: ['The Company']

# %% [markdown]
# ## 3. Table Melting

# %%
melter = TableMelter(entity_id=entity_meta.canonical_id)
table_rows = []

for block in blocks:
    if block.block_type == BlockType.TABLE:
        print(f"Melting table in section: {block.section_path}")
        rows = melter.melt(block)
        table_rows.extend(rows)
        # Print first few for demo
        if rows:
            for r in rows[:3]:
                print(f"  - {r.metric_name} ({r.period_start}): {r.num_value} {r.unit_normalized}")

print(f"Total Table Rows Extracted: {len(table_rows)}")
# Out:
# Melting table in section: ['Securities registered pursuant to Section 12(b) of the Act:']
#   - Common Stock, $0.01 par value (None): None USD
# Melting table in section: ['Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, or smaller reporting company or an emerging growth company.']
#   - Accelerated Filer (None): None USD
#   - Non-Accelerated Filer (None): None USD
#   - Smaller Reporting Company (None): None USD
# Melting table in section: ['COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*']
#   - 100.0 (None): 131.46 USD
#   - 100.0 (None): 113.58 USD
#   - 100.0 (None): 182.46 USD
# Melting table in section: ['Results of Operations']
# Melting table in section: ['Total Company']
# Melting table in section: ['Total Company']
# Melting table in section: ['Selling and Administrative Expenses']
#   - $ 779 (None): 738.0 USD
#   - $ 779 (None): None USD
#   - $ 945 (None): 980.0 USD
# Melting table in section: ['Segment Net Sales']
#   - $ 4,559 (None): None USD
#   - $ 4,559 (None): None USD
#   - $ 4,112 (None): None USD
# Total Table Rows Extracted: 32

# %% [markdown]
# ## 4. Text Extraction (SLM)

# %%
text_synth = TextSynthesizer(entity_id=entity_meta.canonical_id)
text_rows = []

# Only process a few text blocks for demo speed
demo_blocks = [b for b in blocks if b.block_type == BlockType.TEXT and len(b.content) > 100][:3]
demo_blocks
# Out:
# [TextBlock(id='0baa432cc9377f228f238bde67a5fb04', block_type=<BlockType.TEXT: 'text'>, content='[Previous Context: For the fiscal year ended September 30, 2025]\n\nFor the transition period from    to\n\nCommission File Number 001-32833', section_path=['☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934'], page_num=None),
#  TextBlock(id='692bfa3991a782201bc896b06b84981f', block_type=<BlockType.TEXT: 'text'>, content='[Previous Context: For the transition period from    to\n\nCommission File Number 001-32833]\n\n(Exact name of registrant as specified in its charter)', section_path=['TransDigm Group Incorporated'], page_num=None),
#  TextBlock(id='34132be568f29f85ecdce3149a1fb6f4', block_type=<BlockType.TEXT: 'text'>, content='[Previous Context: (Exact name of registrant as specified in its charter)]\n\n(State or other jurisdiction of incorporation or organization)', section_path=['Delaware'], page_num=None)]

# %%
for block in demo_blocks:
    print(f"Extracting from text in: {block.section_path}")
    print(f"Preview: {block.content[:100]}...")
    
    facts = await text_synth.extract_facts(block)
    text_rows.extend(facts)
    
    for f in facts:
        print(f"  -> Extracted: {f.metric_name}: {f.num_value} | Raw: {getattr(f, 'grounding_quote', 'N/A')} | Align: {getattr(f, 'alignment_status', 'N/A')} (Conf: {f.confidence_score})")
        if f.text_nuance:
            print(f"     Nuance: {f.text_nuance}")
            
print(f"Total Text Facts Extracted: {len(text_rows)}")
# Out:
# Extracting from text in: ['☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934']
# Preview: [Previous Context: For the fiscal year ended September 30, 2025]
#
# For the transition period from    ...
#   -> Extracted: Transition Period: None | Raw: For the transition period from    to | Align: EXACT (Conf: 0.7)
#   -> Extracted: Commission File Number: None | Raw: 001-32833 | Align: EXACT (Conf: 0.7)
# Extracting from text in: ['TransDigm Group Incorporated']
# Preview: [Previous Context: For the transition period from    to
#
# Commission File Number 001-32833]
#
# (Exact n...
# Extracting from text in: ['Delaware']
# Preview: [Previous Context: (Exact name of registrant as specified in its charter)]
#
# (State or other jurisdic...
# Total Text Facts Extracted: 2

# %% [markdown]
# Expected:
#
# Extracting from text in: ['☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934']
# Preview: [Previous Context: For the fiscal year ended September 30, 2025]
#
# For the transition period from    ...
#   -> Extracted: Transition Period: None | Raw: For the transition period from    to | Align: EXACT (Conf: 0.7)
#   -> Extracted: Commission File Number: None | Raw: 001-32833 | Align: EXACT (Conf: 0.7)
# Extracting from text in: ['TransDigm Group Incorporated']
# Preview: [Previous Context: For the transition period from    to
#
# Commission File Number 001-32833]
#
# (Exact n...
# Extracting from text in: ['Delaware']
# Preview: [Previous Context: (Exact name of registrant as specified in its charter)]
#
# (State or other jurisdic...
# Total Text Facts Extracted: 2
