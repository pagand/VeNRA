# %% [markdown]
# # Dual-Retriever & Relational Expansion Demo
#
# This notebook demonstrates **Step 1: The Dual-Retriever**.
#
# Unlike standard RAG, VeNRA connects structured data (UFL) and unstructured text (Chunks) bi-directionally using **Relational Expansion** (GraphRAG-style).
#
# ### Verification Workflow:
# 1. **Full Ingestion:** Run the `IngestionPipeline` to ensure `ufl.parquet` and the vector index are persisted.
# 2. **Clue Generation:** Use the Navigator to generate `RetrievalPlan` (Clues).
# 3. **Dual-Retrieval:** Execute the search and observe the relational merging of rows and text.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import json
import nest_asyncio
from dotenv import load_dotenv

# Add src to path
sys.path.append(os.path.abspath("../src"))
load_dotenv("../.env")

from venra.pipeline import IngestionPipeline
from venra.navigator import Navigator
from venra.retriever import DualRetriever
from venra.logging_config import logger

nest_asyncio.apply()
# Out:
# /Users/pedram/Projects/VeNRA/.venv/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validate_default' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'validate_default' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %% [markdown]
# ## 1. Run Pipeline (Ensures Data Persistence)
#
# This will parse the TransDigm 10-K, melt tables into the UFL, and index everything.

# %%
PDF_PATH = "../data/10K_TD_test.pdf"
pipeline = IngestionPipeline()

# Run the full pipeline to create ufl.parquet and index chunks
await pipeline.run(PDF_PATH, skip_parsing=True)
# Out:
# 2026-02-03 14:48:49,005 - venra - INFO - UFL already exists at /Users/pedram/Projects/VeNRA/data/processed/10K_TD_test_ufl.parquet. Skipping extraction.
# [UFLRow(row_id='e65db3dc53e8ddc0d839204d603903a7', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=500000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='☒ Annual Report Pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='f1bb65a4-9938-465d-8a10-db1c7f16795f', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='5cf22b20665502f78ad48a3aee1d2a11', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Rate', value=5.0, unit='Percent', scale_factor=1.0, period='2025', doc_section='☒ Annual Report Pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='f1bb65a4-9938-465d-8a10-db1c7f16795f', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='0ed88d45198ecaf781aedf3a1af9018c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisitions', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='☒ Annual Report Pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='f1bb65a4-9938-465d-8a10-db1c7f16795f', nuance_note='substantially all', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='51cb28b4ce45d66b00167449fe289602', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Divestitures', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='☒ Annual Report Pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='f1bb65a4-9938-465d-8a10-db1c7f16795f', nuance_note='majority of', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='8b3791454390e97f181377d0011c1c96', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Legal Rulings', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='☒ Annual Report Pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='f1bb65a4-9938-465d-8a10-db1c7f16795f', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='5c5a3debe7bb5cdb3b151c53df0ecac5', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Risk Factors', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='☒ Annual Report Pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='f1bb65a4-9938-465d-8a10-db1c7f16795f', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='f462e92c7262ea620fbfeeaeae6b9e07', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=500000000.0, unit='USD', scale_factor=1.0, period='2022', doc_section='☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='ff5abc6f-c486-46da-982c-b3eafca9a246', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='cf4fdf6c3c142d50d294b3134f951ebb', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Income', value=100000000.0, unit='USD', scale_factor=1.0, period='2022', doc_section='☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='ff5abc6f-c486-46da-982c-b3eafca9a246', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='42314f7539f1138d23c92efdc81c8e59', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Rate', value=5.0, unit='Percent', scale_factor=1.0, period='2022', doc_section='☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='ff5abc6f-c486-46da-982c-b3eafca9a246', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='0d529178adaccf417ce5c5ecc75665c1', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisitions', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='ff5abc6f-c486-46da-982c-b3eafca9a246', nuance_note='substantially all', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='c1f2894cf99426bbc3894b1bafa95e24', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Divestitures', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='ff5abc6f-c486-46da-982c-b3eafca9a246', nuance_note='majority of', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='37982354471cb30e6900fa5ad0eb6b83', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Legal Rulings', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='☐ Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934', source_chunk_id='ff5abc6f-c486-46da-982c-b3eafca9a246', nuance_note='approximately', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='8c391f3e25b3cb99bcda8fb03f80d8d7', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Address of principal executive offices', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='41-2101738', source_chunk_id='165476d4-3d5e-4719-8148-dba1e4f41522', nuance_note=None, confidence=1.0, related_entity_id='1350 Euclid Avenue, Suite 1600, Cleveland, Ohio 44115'),
#  UFLRow(row_id='c342b274970be95f47644283d6376702', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Zip Code', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='41-2101738', source_chunk_id='165476d4-3d5e-4719-8148-dba1e4f41522', nuance_note=None, confidence=1.0, related_entity_id='44115'),
#  UFLRow(row_id='a5b0e286eff9e8953be32bf529eb377d', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Common Stock, $0.01 par value', value=nan, unit='USD', scale_factor=1.0, period='Trading Symbol:', doc_section='Securities registered pursuant to Section 12(b) of the Act:', source_chunk_id='e5cb3651-93dc-44df-9515-053f8d9c8d48', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='3a51a7e174b9c4f461444458cd7a1f7f', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Is a well-known seasoned issuer', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='aa0d169a-c423-4ab5-a3f6-64dc506167f3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='9dd2e92200367f1c27433858de0cf01c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Is not required to file reports pursuant to Section 13 or Section 15(d) of the Act', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='aa0d169a-c423-4ab5-a3f6-64dc506167f3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='fd54f253bb2d7054adc10f685db3af36', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 months', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='aa0d169a-c423-4ab5-a3f6-64dc506167f3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='a2625370d280be4df668c44e172b4c69', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Has been subject to such filing requirements for the past 90 days', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='aa0d169a-c423-4ab5-a3f6-64dc506167f3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='c61fc0246fb8d1ad7870aa013099df1c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T during the preceding 12 months', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='aa0d169a-c423-4ab5-a3f6-64dc506167f3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='00699f78e205156abed9de091b4f198a', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Is a large accelerated filer, an accelerated filer, a non-accelerated filer, or smaller reporting company or an emerging growth company', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='aa0d169a-c423-4ab5-a3f6-64dc506167f3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='28a3be486d758a4ce18c0ca83ad11bd5', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Accelerated Filer', value=nan, unit='USD', scale_factor=1.0, period='☒', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='ed3e4adc-dbe3-4c0f-95f2-e4efa9cf8094', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='d3b2aefd79edb020b64c83cb57065942', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Non-Accelerated Filer', value=nan, unit='USD', scale_factor=1.0, period='☒', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='ed3e4adc-dbe3-4c0f-95f2-e4efa9cf8094', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='c7f9487d923fc40aa5ed12460e14f72e', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Smaller Reporting Company', value=nan, unit='USD', scale_factor=1.0, period='☒', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='ed3e4adc-dbe3-4c0f-95f2-e4efa9cf8094', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='8526101ebba8053269e3e178347fbbc9', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Emerging Growth Company', value=nan, unit='USD', scale_factor=1.0, period='☒', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='ed3e4adc-dbe3-4c0f-95f2-e4efa9cf8094', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='d9701853576f60fbe9d553b0e5a6c088', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=1200000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='13075183dd2ce0bab938cc7e41fb2885', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net income', value=250000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='7145515c9846c510c185d37d4ab60867', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest expense', value=110000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='497f1f6d1f78a6637643de3978cdb70d', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Dividend per share', value=0.15, unit='Percent', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='5929a6bb1e7fed20554bc02cf9b66474', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Total assets', value=1500000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='edbc94710ce2f9f0c53249ee8fd2d561', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Total liabilities', value=850000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='4abda410d160fb7211aef717c188f19c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Cash and cash equivalents', value=250000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='256c53f6ca75119302e4a7423ded79b7', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Accounts receivable', value=120000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='00c109ca26146b8599592fec038f5496', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Property, plant, and equipment', value=550000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='0c35715c5d5e43e988f605e5b22434a1', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Goodwill', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note='Impairment', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='7176802043e1e3432ebde33fc9d45b19', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net operating loss carryforward', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note='Tax benefit', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='8ce34007a35f967a73f9315eb8792165', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Risk factor', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='0f364dbb-137e-4ca1-aacc-d6a1a75934b8', nuance_note='Regulatory risk', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='d68a082d2754ae068eff95c75edf2b5e', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Aggregate Market Value', value=76426902522.0, unit='USD', scale_factor=1.0, period='2025-03-28', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='f41f0de6-0551-448a-bb9a-3583b7c20372', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='5176760935207b12376ad19fbfa44693', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of Shares Outstanding', value=56318584.0, unit='Shares', scale_factor=1.0, period='2025-10-31', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='f41f0de6-0551-448a-bb9a-3583b7c20372', nuance_note=None, confidence=1.0, related_entity_id='TransDigm Group Incorporated'),
#  UFLRow(row_id='cb230a9a7f55bde7c944743384d2a2c4', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=nan, unit=None, scale_factor=1.0, period='2022', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='e875c6c8-c402-466b-8fcc-96c10b05eb45', nuance_note=None, confidence=0.8, related_entity_id=None),
#  UFLRow(row_id='8fee14e4d4139844162c46c294c93375', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisitions', value=nan, unit=None, scale_factor=1.0, period='2022', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='e875c6c8-c402-466b-8fcc-96c10b05eb45', nuance_note='substantially all', confidence=0.9, related_entity_id=None),
#  UFLRow(row_id='9cd6a217e7a3170ae4ad03db8a27e67d', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Rate', value=5.0, unit='Percent', scale_factor=1.0, period='2022', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='e875c6c8-c402-466b-8fcc-96c10b05eb45', nuance_note=None, confidence=0.7, related_entity_id=None),
#  UFLRow(row_id='1b5ed39618505123ba6b0df4fba17e77', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Divestitures', value=nan, unit=None, scale_factor=1.0, period='2022', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='e875c6c8-c402-466b-8fcc-96c10b05eb45', nuance_note='majority of', confidence=0.8, related_entity_id=None),
#  UFLRow(row_id='2f2e036f906c782e362b0ece83a25664', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Adjusted Income', value=100000000.0, unit='USD', scale_factor=1.0, period='2022', doc_section='Securities registered pursuant to Section 12(g) of the Act:', source_chunk_id='e875c6c8-c402-466b-8fcc-96c10b05eb45', nuance_note='Adjusted for non-recurring items', confidence=0.9, related_entity_id=None),
#  UFLRow(row_id='f702a43497a22be5c15fd3817794c484', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Years of experience of VPoC', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='66ffe064-ea3b-4749-b86a-9eb0ae5deaec', nuance_note='over 35 years', confidence=1.0, related_entity_id='VPoC'),
#  UFLRow(row_id='b091673619091f497261918afbe700f1', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of executives in IRT', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='66ffe064-ea3b-4749-b86a-9eb0ae5deaec', nuance_note='made up of the Co-Chief Operating Officers, Chief Financial Officer, and executives in legal, finance, IT, and audit', confidence=1.0, related_entity_id='IRT'),
#  UFLRow(row_id='8a4501efe2f6ce8f90ddb21e59125b81', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of businesses', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='66ffe064-ea3b-4749-b86a-9eb0ae5deaec', nuance_note='adopted by our businesses', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='49aa6822bafbf18db05ca4fc1dee6ea7', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of exercises of incident response plan', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='66ffe064-ea3b-4749-b86a-9eb0ae5deaec', nuance_note='regular exercises', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='5f9e6a886a4edc0f90e493e1c56ad72b', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of meetings of Audit Committee and/or full Board of Directors', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='66ffe064-ea3b-4749-b86a-9eb0ae5deaec', nuance_note='as appropriate', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='5eef31a23cfbc0311beba8389cef5ef8', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of third-party forensic vendor(s)', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='66ffe064-ea3b-4749-b86a-9eb0ae5deaec', nuance_note='available for incident response and investigation', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='11c44c8d4b4fc7581c32d3a5985a67ae', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of cybersecurity insurance', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='66ffe064-ea3b-4749-b86a-9eb0ae5deaec', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='c7a188b7871308d158429f8a6fae5e05', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=500000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='ccf4be5d-acef-491a-b47e-5bc9cafc8fcf', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='ca4c52f633308c48895c7e3f7e93fa80', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Rate', value=15.0, unit='Percent', scale_factor=1.0, period='2023', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='ccf4be5d-acef-491a-b47e-5bc9cafc8fcf', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='7ead752f0bda16cc89b7dc6a35032e39', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisitions', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='ccf4be5d-acef-491a-b47e-5bc9cafc8fcf', nuance_note='substantially all', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='1249485abd88f1f38c4dac5ce0b20fee', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Divestitures', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='ccf4be5d-acef-491a-b47e-5bc9cafc8fcf', nuance_note='majority of', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='2be4b45df32470c935442b9857a3d056', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Legal Rulings', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='ccf4be5d-acef-491a-b47e-5bc9cafc8fcf', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='11f29e93883b27edc75fb22b94447343', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Risk Factors', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 1C. CYBERSECURITY', source_chunk_id='ccf4be5d-acef-491a-b47e-5bc9cafc8fcf', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='ad3404d4d5e34c4747fac9a4466fa435', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of manufacturing facilities', value=120.0, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 2. PROPERTIES', source_chunk_id='e13abe29-c3e2-4c91-916b-efeb91cbaf2a', nuance_note='approximately', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='e0829255a379c65c21a0d2345efe948c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of states within the United States', value=25.0, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 2. PROPERTIES', source_chunk_id='e13abe29-c3e2-4c91-916b-efeb91cbaf2a', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='985397f6be12bb104f584f52e5eda7d6', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of other countries', value=14.0, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 2. PROPERTIES', source_chunk_id='e13abe29-c3e2-4c91-916b-efeb91cbaf2a', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='7dab0890141d57ad7e034cd905b196fb', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of facilities that are individually material to operations', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 2. PROPERTIES', source_chunk_id='e13abe29-c3e2-4c91-916b-efeb91cbaf2a', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='e469c20321de60c43969063034f1c937', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of facilities with certain administrative functions', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 2. PROPERTIES', source_chunk_id='e13abe29-c3e2-4c91-916b-efeb91cbaf2a', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='df2224ad346920ac612e9321223f2993', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Monetary sanctions threshold', value=1000000.0, unit='USD', scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 3. LEGAL PROCEEDINGS', source_chunk_id='1fd9dc37-568d-4193-a582-581b98866d0c', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='de3cece970e0e3af05466d014913abf1', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Material adverse effect threshold', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 3. LEGAL PROCEEDINGS', source_chunk_id='1fd9dc37-568d-4193-a582-581b98866d0c', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='378c85d5fc126bbb0c9d264208079330', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of Stockholders of Record', value=27.0, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Holders', source_chunk_id='317a2378-c68f-44a3-a4c6-d199f6950093', nuance_note=None, confidence=1.0, related_entity_id='Common Stock'),
#  UFLRow(row_id='57d712e05fc5a9b96a8e5559e5b2f966', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Number of Beneficial Stockholders', value=908000.0, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Holders', source_chunk_id='317a2378-c68f-44a3-a4c6-d199f6950093', nuance_note='Estimated', confidence=1.0, related_entity_id='Common Stock'),
#  UFLRow(row_id='6b3cbb77876fc727ac6c2af3e1a85cc3', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=nan, unit=None, scale_factor=1.0, period='2023', doc_section='Holders', source_chunk_id='bbee0a39-2a75-4372-97cf-fd094ce90ef7', nuance_note=None, confidence=0.8, related_entity_id=None),
#  UFLRow(row_id='9c32b3fc799c18ec6839397e196e3166', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisitions', value=nan, unit=None, scale_factor=1.0, period='2023', doc_section='Holders', source_chunk_id='bbee0a39-2a75-4372-97cf-fd094ce90ef7', nuance_note='substantially all', confidence=0.7, related_entity_id=None),
#  UFLRow(row_id='d378d3d5988cf8605d0a3b33a18070be', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Rate', value=5.0, unit='Percent', scale_factor=1.0, period='2023', doc_section='Holders', source_chunk_id='bbee0a39-2a75-4372-97cf-fd094ce90ef7', nuance_note=None, confidence=0.9, related_entity_id=None),
#  UFLRow(row_id='5048e1deb510c5c336b1e93331e2d864', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Divestitures', value=nan, unit=None, scale_factor=1.0, period='2023', doc_section='Holders', source_chunk_id='bbee0a39-2a75-4372-97cf-fd094ce90ef7', nuance_note='majority of', confidence=0.6, related_entity_id=None),
#  UFLRow(row_id='9117a79d9ec812481829325614438c45', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Special Cash Dividend', value=90.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Special Dividends', source_chunk_id='4dd792ff-5bf3-41d7-8a77-9c1af3c9b6a6', nuance_note=None, confidence=1.0, related_entity_id='Common Stock'),
#  UFLRow(row_id='12c1a7a298e8c047371bbcfa029c1082', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Total Cash Payment', value=5232000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Special Dividends', source_chunk_id='4dd792ff-5bf3-41d7-8a77-9c1af3c9b6a6', nuance_note='Approximately', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='2bbe1e18917d1fd8ac1310239b65d137', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='New Senior Secured and Unsecured Debt', value=5000000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Special Dividends', source_chunk_id='4dd792ff-5bf3-41d7-8a77-9c1af3c9b6a6', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='3e3d3b279dc799521e0406ec5de96063', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Investment Amount', value=100.0, unit='USD', scale_factor=1.0, period='2020', doc_section='Performance Graph', source_chunk_id='bfcdfae5-f68a-4264-9e51-38ac07688874', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='89385385e4a718fa35b81e0451a610b1', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Reinvestment of Dividends', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Performance Graph', source_chunk_id='bfcdfae5-f68a-4264-9e51-38ac07688874', nuance_note='Assumed reinvestment of all dividends', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='cc7ef93446496c48aa23bf2f40f59d44', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Tracking Period Start', value=nan, unit=None, scale_factor=1.0, period='September 30, 2020', doc_section='Performance Graph', source_chunk_id='bfcdfae5-f68a-4264-9e51-38ac07688874', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='a5cd0fde8838c09301ba550f07b2939a', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Tracking Period End', value=nan, unit=None, scale_factor=1.0, period='September 30, 2025', doc_section='Performance Graph', source_chunk_id='bfcdfae5-f68a-4264-9e51-38ac07688874', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='310a878021ed12010b8191e21b1f13a2', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=nan, unit=None, scale_factor=1.0, period='2022', doc_section='Performance Graph', source_chunk_id='35040419-27e4-4429-aade-2e5bacc8e770', nuance_note=None, confidence=0.8, related_entity_id=None),
#  UFLRow(row_id='b49058319a3a4d02acdaa7cc604dc2f0', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Rate', value=5.0, unit='Percent', scale_factor=1.0, period='2022', doc_section='Performance Graph', source_chunk_id='35040419-27e4-4429-aade-2e5bacc8e770', nuance_note=None, confidence=0.9, related_entity_id=None),
#  UFLRow(row_id='dc0e1edae9939d04cb14a6d227244919', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisitions', value=nan, unit=None, scale_factor=1.0, period='2022', doc_section='Performance Graph', source_chunk_id='35040419-27e4-4429-aade-2e5bacc8e770', nuance_note='substantially all', confidence=0.7, related_entity_id=None),
#  UFLRow(row_id='f5106143e7e0675bb2e8b27049db1e7c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Divestitures', value=nan, unit=None, scale_factor=1.0, period='2022', doc_section='Performance Graph', source_chunk_id='35040419-27e4-4429-aade-2e5bacc8e770', nuance_note='majority of', confidence=0.6, related_entity_id=None),
#  UFLRow(row_id='72a883a052c5bdb19b0b1e3ed2236104', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Related Information', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Table of Contents', source_chunk_id='519be1c0-4b7a-4297-9d25-ecd8fc9aeedc', nuance_note='Not deemed soliciting material nor to be filed with the SEC, nor shall such information be incorporated by reference into any future filings under the Securities Act of 1933 or the Securities Exchange Act of 1934, each as amended, except to the extent we specifically incorporate it by reference into such filing.', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='50e7126956d549e6e0e7b3feeb5c8852', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Performance Graph', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='Table of Contents', source_chunk_id='519be1c0-4b7a-4297-9d25-ecd8fc9aeedc', nuance_note='Not deemed soliciting material nor to be filed with the SEC, nor shall such information be incorporated by reference into any future filings under the Securities Act of 1933 or the Securities Exchange Act of 1934, each as amended, except to the extent we specifically incorporate it by reference into such filing.', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='f5302f38bc960432724446c07e6af425', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='TransDigm Group Inc. 5-Year Cumulative Total Return', value=nan, unit=None, scale_factor=1.0, period='2023', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='e5313fa0-444e-47f1-932e-fefdf2eff758', nuance_note=None, confidence=1.0, related_entity_id='TransDigm Group Inc.'),
#  UFLRow(row_id='eddfbe737e0e65f1372a9f1d31ba8a4b', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S&#x26;P 500 Index 5-Year Cumulative Total Return', value=nan, unit=None, scale_factor=1.0, period='2023', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='e5313fa0-444e-47f1-932e-fefdf2eff758', nuance_note=None, confidence=1.0, related_entity_id='S&#x26;P 500 Index'),
#  UFLRow(row_id='b17111bd2af937ca13a9612ca31b8e28', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S&#x26;P Aerospace &#x26; Defense Select Industry Index 5-Year Cumulative Total Return', value=nan, unit=None, scale_factor=1.0, period='2023', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='e5313fa0-444e-47f1-932e-fefdf2eff758', nuance_note=None, confidence=1.0, related_entity_id='S&#x26;P Aerospace &#x26; Defense Select Industry Index'),
#  UFLRow(row_id='7f69e67b5b3584c9b4995e898d344ebf', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Return', value=nan, unit=None, scale_factor=1.0, period='2020', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='0e2eb9eb-0bce-4201-a212-1b4fc07e6d97', nuance_note='As of 9/30/2020', confidence=1.0, related_entity_id='TransDigm Group Inc.'),
#  UFLRow(row_id='7f69e67b5b3584c9b4995e898d344ebf', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Return', value=nan, unit=None, scale_factor=1.0, period='2020', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='0e2eb9eb-0bce-4201-a212-1b4fc07e6d97', nuance_note='As of 9/30/2020', confidence=1.0, related_entity_id='S&#x26;P 500 Index'),
#  UFLRow(row_id='7f69e67b5b3584c9b4995e898d344ebf', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Return', value=nan, unit=None, scale_factor=1.0, period='2020', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='0e2eb9eb-0bce-4201-a212-1b4fc07e6d97', nuance_note='As of 9/30/2020', confidence=1.0, related_entity_id='S&#x26;P Aerospace &#x26; Defense Select Industry Index'),
#  UFLRow(row_id='86929c0a5b375f904cebd538929ca105', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='TransDigm Group Inc.', value=100.0, unit='USD', scale_factor=1.0, period='9/30/2020', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='9db049d0b0d77d78d0f11cc5fc4ab75c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='TransDigm Group Inc.', value=131.46, unit='USD', scale_factor=1.0, period='9/30/2021', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='c0b909eaff7d740f5101c88155345cd9', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='TransDigm Group Inc.', value=113.58, unit='USD', scale_factor=1.0, period='9/30/2022', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='13e5004077c50cab9ca63fd642aec6cd', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='TransDigm Group Inc.', value=182.46, unit='USD', scale_factor=1.0, period='9/30/2023', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='c41dfdba05804d436105a6d24aad380a', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='TransDigm Group Inc.', value=320.14, unit='USD', scale_factor=1.0, period='9/30/2024', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='228d23dbfaa9d43e88e14b8f26e1e311', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='TransDigm Group Inc.', value=333.54, unit='USD', scale_factor=1.0, period='9/30/2025', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='2d81ac09e76c06c06053a6902b8ab773', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P 500 Index', value=100.0, unit='USD', scale_factor=1.0, period='9/30/2020', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='6d9a4102bd306a9543cc875e0d91493a', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P 500 Index', value=130.01, unit='USD', scale_factor=1.0, period='9/30/2021', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='2119cde94d9da963c0c7dbf34d682185', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P 500 Index', value=109.89, unit='USD', scale_factor=1.0, period='9/30/2022', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='ce2161ea53519e725b8914ff43eb502e', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P 500 Index', value=133.65, unit='USD', scale_factor=1.0, period='9/30/2023', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='d87d647fd77e178efd7ed40efb75d489', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P 500 Index', value=182.23, unit='USD', scale_factor=1.0, period='9/30/2024', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='24ead1c96b9293dd6c506305e3fbd4a4', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P 500 Index', value=214.3, unit='USD', scale_factor=1.0, period='9/30/2025', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='aee73dc7b0b2ffbdd905a49689f781b1', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P Aerospace & Defense Select Industry Index', value=100.0, unit='USD', scale_factor=1.0, period='9/30/2020', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='61cc603e43d8f1ba862dba4853be3daa', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P Aerospace & Defense Select Industry Index', value=138.28, unit='USD', scale_factor=1.0, period='9/30/2021', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='b32e15d6190dbb0075d9648f79863f2b', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P Aerospace & Defense Select Industry Index', value=107.07, unit='USD', scale_factor=1.0, period='9/30/2022', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='51e15fbe332f545d0fa35e60c617b41f', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P Aerospace & Defense Select Industry Index', value=132.01, unit='USD', scale_factor=1.0, period='9/30/2023', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='6194e753f88c7f6cf1bbda881446a318', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P Aerospace & Defense Select Industry Index', value=187.1, unit='USD', scale_factor=1.0, period='9/30/2024', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='9ca0a73081434c9b756398888e6fd224', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='S\\&P Aerospace & Defense Select Industry Index', value=282.62, unit='USD', scale_factor=1.0, period='9/30/2025', doc_section='COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*', source_chunk_id='4c75a3b4-756c-4f4f-b3c9-819a6a6f0e14', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='e8458507a9c9ce7de3aa1971baadc557', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='No purchases of equity securities', value=nan, unit=None, scale_factor=1.0, period='2025', doc_section='Purchases of Equity Securities by the Issuer or Affiliated Purchaser', source_chunk_id='57c8b3a3-585c-4732-b564-fc4655a3d5eb', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='ab6627de4d50d264017ecffbcead59bd', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Stock repurchase program', value=nan, unit=None, scale_factor=1.0, period='2025', doc_section='Purchases of Equity Securities by the Issuer or Affiliated Purchaser', source_chunk_id='57c8b3a3-585c-4732-b564-fc4655a3d5eb', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='d25e4c811f6ae915afc09e28975d75ed', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=1200000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='ITEM 6.          [RESERVED]', source_chunk_id='14cb7f18-878b-4ea8-af32-1566879561e3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='651a2a8784ec0b9cc41a2659b681d10a', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Income', value=250000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='ITEM 6.          [RESERVED]', source_chunk_id='14cb7f18-878b-4ea8-af32-1566879561e3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='7c9163f2f4f40206e50418a103fc750e', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Expense', value=110000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='ITEM 6.          [RESERVED]', source_chunk_id='14cb7f18-878b-4ea8-af32-1566879561e3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='1de8006d8ec89887f4987eda2849a09d', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Dividend Payout Ratio', value=15.0, unit='Percent', scale_factor=1.0, period='2023', doc_section='ITEM 6.          [RESERVED]', source_chunk_id='14cb7f18-878b-4ea8-af32-1566879561e3', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='f26c96760a5c4e98b5adb63e2c883962', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisitions', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 6.          [RESERVED]', source_chunk_id='14cb7f18-878b-4ea8-af32-1566879561e3', nuance_note='Substantially all', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='4e226d5421384ddb429bcc6d4c4e2682', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Risk Factors', value=nan, unit=None, scale_factor=1.0, period='UNKNOWN', doc_section='ITEM 6.          [RESERVED]', source_chunk_id='14cb7f18-878b-4ea8-af32-1566879561e3', nuance_note='Material uncertainty', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='b8b77182b9e4cd10887efcaed512cb92', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Revenue', value=500000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='ITEM 6.          [RESERVED]', source_chunk_id='ef20db53-a1e5-4594-9298-b16efcfa50ea', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='7d6d2484f64d4bf912bc8d1d22c18667', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Rate', value=15.0, unit='Percent', scale_factor=1.0, period='2023', doc_section='ITEM 6.          [RESERVED]', source_chunk_id='ef20db53-a1e5-4594-9298-b16efcfa50ea', nuance_note=None, confidence=1.0, related_entity_id=None),
# ...
#  UFLRow(row_id='4bbb755033e334bd06df029b92397b5f', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Non-cash stock and deferred compensation expense', value=142.0, unit='USD', scale_factor=1.0, period='September 30, 2025', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='fecdff39e6a4a5b011fa335c44b4065a', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Non-cash stock and deferred compensation expense', value=196.0, unit='USD', scale_factor=1.0, period='September 30, 2024', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='8d5e4163eae116c89658d00d6edf3276', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='% of net sales', value=nan, unit='USD', scale_factor=1.0, period='September 30, 2025', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='b8235a3bfdc48a26d017c49fef57b576', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='% of net sales', value=nan, unit='USD', scale_factor=1.0, period='September 30, 2024', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='35e16e7827c18d4f050bbb6bb6d5dd74', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisition transaction and integration-related expenses', value=24.0, unit='Ratio', scale_factor=1.0, period='September 30, 2025', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='5dc158d79575d8cc320758510342b9f4', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisition transaction and integration-related expenses', value=46.0, unit='Ratio', scale_factor=1.0, period='September 30, 2024', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='8d5e4163eae116c89658d00d6edf3276', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='% of net sales', value=nan, unit='USD', scale_factor=1.0, period='September 30, 2025', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='b8235a3bfdc48a26d017c49fef57b576', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='% of net sales', value=nan, unit='USD', scale_factor=1.0, period='September 30, 2024', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='8efd83069d4bf8ec6e2ca24f929265db', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Total selling and administrative expenses', value=980.0, unit='USD', scale_factor=1.0, period='September 30, 2025', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='b54d44a478a300101d397c538f536f98', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Total selling and administrative expenses', value=nan, unit='USD', scale_factor=1.0, period='September 30, 2024', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='8d5e4163eae116c89658d00d6edf3276', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='% of net sales', value=nan, unit='USD', scale_factor=1.0, period='September 30, 2025', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='b8235a3bfdc48a26d017c49fef57b576', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='% of net sales', value=nan, unit='USD', scale_factor=1.0, period='September 30, 2024', doc_section='Selling and Administrative Expenses', source_chunk_id='8061498a-cc60-4a2b-8bd3-8ba0b6f932d8', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='586914042d38a78ca4a088f3d5635840', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Non-cash stock and deferred compensation expense', value=nan, unit=None, scale_factor=1.0, period='2024', doc_section='Selling and Administrative Expenses', source_chunk_id='8097d00f-7683-43d7-bd70-15a3ae138864', nuance_note='appreciation of the stock price at a higher rate in fiscal 2024 compared to fiscal 2025', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='728548a61f434f155863242372513ccd', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Non-cash stock and deferred compensation expense', value=nan, unit=None, scale_factor=1.0, period='2025', doc_section='Selling and Administrative Expenses', source_chunk_id='8097d00f-7683-43d7-bd70-15a3ae138864', nuance_note='lower deferred compensation expense', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='5501dc7d75435f99a008e37121f71e0a', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Expense-net', value=1572000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Interest Expense-net', source_chunk_id='1ee5903a-8c99-467e-8e8b-4d5277d561e1', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='09ad5c77a1a2aa1de19dad47e18bdf66', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Expense-net', value=1286000000.0, unit='USD', scale_factor=1.0, period='2024', doc_section='Interest Expense-net', source_chunk_id='1ee5903a-8c99-467e-8e8b-4d5277d561e1', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='d559942f8cb26a1ed34bb015dc5faf7d', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Expense-net Increase', value=286000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Interest Expense-net', source_chunk_id='1ee5903a-8c99-467e-8e8b-4d5277d561e1', nuance_note='Increase of 22.2%', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='4999fbeebce126de36a4fae0c98c4265', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Interest Expense-net Increase Percentage', value=22.2, unit='Percent', scale_factor=1.0, period='2025', doc_section='Interest Expense-net', source_chunk_id='1ee5903a-8c99-467e-8e8b-4d5277d561e1', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='ac73915a501ab26492c693d89158a6e7', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Weighted Average Interest Rate', value=6.3, unit='Percent', scale_factor=1.0, period='2025', doc_section='Interest Expense-net', source_chunk_id='1ee5903a-8c99-467e-8e8b-4d5277d561e1', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='38d2e047683a81daadd8b16d53831a0e', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Weighted Average Interest Rate', value=6.3, unit='Percent', scale_factor=1.0, period='2024', doc_section='Interest Expense-net', source_chunk_id='1ee5903a-8c99-467e-8e8b-4d5277d561e1', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='4016842945ed3dca21ba9a560a9c25c6', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Income Tax Expense as a Percentage of Income Before Income Taxes', value=21.1, unit='Percent', scale_factor=1.0, period='2025', doc_section='Income Tax Provision', source_chunk_id='b348df7a-6678-4a84-b5d6-2718f9ea518f', nuance_note='approximately', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='b50b6739b2ef118d0429f36d572c7c50', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Income Tax Expense as a Percentage of Income Before Income Taxes', value=22.6, unit='Percent', scale_factor=1.0, period='2024', doc_section='Income Tax Provision', source_chunk_id='b348df7a-6678-4a84-b5d6-2718f9ea518f', nuance_note='approximately', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='e92d5010c02e82b1f6e0f9a2bf559bd4', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Basic and Diluted Earnings per Share', value=32.08, unit='USD', scale_factor=1.0, period='2025', doc_section='Earnings per Share', source_chunk_id='3ccea2b4-e861-42bc-8237-1e1eda5b8672', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='d5d498307e55a31170d05d282b14974c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Basic and Diluted Earnings per Share', value=25.62, unit='USD', scale_factor=1.0, period='2024', doc_section='Earnings per Share', source_chunk_id='3ccea2b4-e861-42bc-8237-1e1eda5b8672', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='7c46ebb78084038b0404bddb29d6a892', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Income Attributable to TD Group', value=2074000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Earnings per Share', source_chunk_id='3ccea2b4-e861-42bc-8237-1e1eda5b8672', nuance_note='Decreased by dividend equivalents of $208 million, or $3.58 per share', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='5b3b39b808af74e34208f58bc8e461af', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Income Attributable to TD Group', value=1714000000.0, unit='USD', scale_factor=1.0, period='2024', doc_section='Earnings per Share', source_chunk_id='3ccea2b4-e861-42bc-8237-1e1eda5b8672', nuance_note='Decreased by dividend equivalents of $233 million, or $4.02 per share', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='0417c406828cb7fa4580a7921fbc94e3', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Income Applicable to TD Group Common Stockholders', value=1866000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Earnings per Share', source_chunk_id='3ccea2b4-e861-42bc-8237-1e1eda5b8672', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='8cd26f2351a436727ffffe61cdaa5311', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Income Applicable to TD Group Common Stockholders', value=1481000000.0, unit='USD', scale_factor=1.0, period='2024', doc_section='Earnings per Share', source_chunk_id='3ccea2b4-e861-42bc-8237-1e1eda5b8672', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='54f0bdc2f8cc7559ae232b946c1e0220', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Sales', value=500000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Business Segments', source_chunk_id='0adc8287-2fc7-411d-ab57-9e5e65da4965', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='10744edf2fc939570d3c6d833158df41', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Sales', value=500000000.0, unit='USD', scale_factor=1.0, period='2024', doc_section='Business Segments', source_chunk_id='0adc8287-2fc7-411d-ab57-9e5e65da4965', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='42d7649c596351b5b24e4d05ba088bcc', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Power & Control', value=nan, unit='USD', scale_factor=1.0, period='2025', doc_section='Business Segments', source_chunk_id='004d6122-6602-4819-a2cb-112b4008f41c', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='b912b5ccadd570e913149bb88fbe6f14', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Power & Control', value=nan, unit='USD', scale_factor=1.0, period='2024', doc_section='Business Segments', source_chunk_id='004d6122-6602-4819-a2cb-112b4008f41c', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='046e316b888ac5a40324f6a2a70087b5', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Airframe', value=nan, unit='USD', scale_factor=1.0, period='2025', doc_section='Business Segments', source_chunk_id='004d6122-6602-4819-a2cb-112b4008f41c', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='2a4742b9c3e9bc2b5262d964c677a82f', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Airframe', value=nan, unit='USD', scale_factor=1.0, period='2024', doc_section='Business Segments', source_chunk_id='004d6122-6602-4819-a2cb-112b4008f41c', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='44d0b92dc9fa346d88d39bf2497b025b', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Non-aviation', value=nan, unit='USD', scale_factor=1.0, period='2025', doc_section='Business Segments', source_chunk_id='004d6122-6602-4819-a2cb-112b4008f41c', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='2e92f5a2e1ba7618eff7d22acc380e80', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Non-aviation', value=nan, unit='USD', scale_factor=1.0, period='2024', doc_section='Business Segments', source_chunk_id='004d6122-6602-4819-a2cb-112b4008f41c', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='43d920ace36fb6dd51c94803a5fd8003', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net sales', value=nan, unit='USD', scale_factor=1.0, period='2025', doc_section='Business Segments', source_chunk_id='004d6122-6602-4819-a2cb-112b4008f41c', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='ff7754e3eb8e6c95de2158bd5d3d2009', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net sales', value=nan, unit='USD', scale_factor=1.0, period='2024', doc_section='Business Segments', source_chunk_id='004d6122-6602-4819-a2cb-112b4008f41c', nuance_note=None, confidence=0.0, related_entity_id=None),
#  UFLRow(row_id='6ab263a3ba31915c32d3eb7f6367c472', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net sales increase for Power & Control segment', value=593000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Business Segments', source_chunk_id='314fe7fb-2dc7-4dd4-bbe8-828e174abb76', nuance_note='primarily from increases in organic sales in defense, commercial aftermarket and commercial OEM', confidence=1.0, related_entity_id='Power & Control segment'),
#  UFLRow(row_id='ce72ce6e638f9295c60530d470eb59bd', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net sales increase for Airframe segment', value=303000000.0, unit='USD', scale_factor=1.0, period='2023', doc_section='Business Segments', source_chunk_id='314fe7fb-2dc7-4dd4-bbe8-828e174abb76', nuance_note='primarily from increases in organic sales in defense and commercial aftermarket', confidence=1.0, related_entity_id='Airframe segment')]

# %% [markdown]
# ## 2. Initialize Components

# %%
file_prefix = os.path.basename(PDF_PATH).replace(".pdf", "")
nav = Navigator(file_prefix=file_prefix)
retriever = DualRetriever(file_prefix=file_prefix)
# Out:
# 2026-02-03 14:49:34,559 - venra - INFO - Retriever loaded UFL with 253 rows.

# %% [markdown]
# ## 3. Clue Generation -> Hybrid Retrieval
#
# We ask about acquisitions. The Navigator provides the clues, and the Retriever executes both branches.

# %%
query = "How much the sale excluding acquisition increase compare to last year and what it was due to?"
plan = await nav.navigate(query)

print(f"--- Clues for: {query} ---")
print(f"Reasoning: {plan.reasoning}")
if plan.ufl_query:
    print(f"UFL Keywords: {plan.ufl_query.metric_keywords}")
print(f"Hypothesis:   {plan.vector_hypothesis}")

# Execute Retrieval with expansion enabled
results = await retriever.retrieve(
    plan, 
    k=3, 
    include_all_chunks_for_ufl=True, 
    include_all_ufl_for_chunks=True
)

print(f"\n--- Results ---")
print(f"Total UFL Rows: {len(results['ufl_rows'])}")
print(f"Total Chunks:   {len(results['text_chunks'])}")

print(f"\n--- Sample UFL Rows ---")
for r in results["ufl_rows"][:5]:
    print(f"- {r.metric_name} ({r.period}): {r.value} {r.unit}")
# Out:
# 2026-02-03 14:56:39,743 - venra - INFO - Navigating query: How much the sale excluding acquisition increase compare to last year and what it was due to?
# 2026-02-03 14:56:40,423 - venra - INFO - Plan generated. Reasoning: The user is asking for the increase in net sales excluding acquisition compared to last year and what it was due to. This requires looking at the entity ID 'ID_TDG' and metrics 'Net Sales', 'Acquisition Sales', and 'Increase in Organic Sales' for the years '2024' and '2023'.
# --- Clues for: How much the sale excluding acquisition increase compare to last year and what it was due to? ---
# Reasoning: The user is asking for the increase in net sales excluding acquisition compared to last year and what it was due to. This requires looking at the entity ID 'ID_TDG' and metrics 'Net Sales', 'Acquisition Sales', and 'Increase in Organic Sales' for the years '2024' and '2023'.
# UFL Keywords: ['Net Sales', 'Acquisition Sales', 'Increase in Organic Sales']
# Hypothesis:   Net Sales Excluding Acquisition Increase Compared to Last Year
# 2026-02-03 14:56:40,425 - venra - INFO - Starting retrieval for query: Net Sales Excluding Acquisition Increase Compared ...
# 2026-02-03 14:56:40,807 - venra - INFO - Retrieval complete: 20 UFL rows, 4 text chunks.
#
# --- Results ---
# Total UFL Rows: 20
# Total Chunks:   4
#
# --- Sample UFL Rows ---
# - Net Sales (2024): 500000000.0 USD
# - Acquisition Sales (2024): nan None
# - Net Sales (2024): 500000000.0 USD
# - Net Sales (2025): 500000000.0 USD
# - Net Organic Sales (2025): nan None

# %%
results['ufl_rows']
# Out:
# [UFLRow(row_id='c7ff6dac0728f1b924f80b5f1f504c56', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Sales', value=500000000.0, unit='USD', scale_factor=1.0, period='2024', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='8c51683e431208c414e06943746ab253', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisition Sales', value=nan, unit=None, scale_factor=1.0, period='2024', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='10744edf2fc939570d3c6d833158df41', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Sales', value=500000000.0, unit='USD', scale_factor=1.0, period='2024', doc_section='Business Segments', source_chunk_id='0adc8287-2fc7-411d-ab57-9e5e65da4965', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='7d339b31d9fab3372f267495734f8685', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Sales', value=500000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='66afcf4f9afc0f03a0d34876efa27a9f', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Organic Sales', value=nan, unit=None, scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='faa297fe284debe02452ef085e6a236b', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Organic Sales', value=nan, unit=None, scale_factor=1.0, period='2024', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='9253ddcec69200773381fc5df22b0a84', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisition Sales', value=nan, unit=None, scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='830b3c766dfa088e4562aefb1b91fc1b', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Dollar Change', value=nan, unit=None, scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='90b17e0871b8ee02a34e60b217d67caf', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Dollar Change', value=nan, unit=None, scale_factor=1.0, period='2024', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='68dd259e028c85858a2de0d0df4fd6e3', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Percentage Change', value=nan, unit='Percent', scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='a7281c458a03bce0391758f48a7aeaa5', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Percentage Change', value=nan, unit='Percent', scale_factor=1.0, period='2024', doc_section='Total Company', source_chunk_id='9d7492d3-c7c0-44b7-b666-f112cb7ff135', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='cc2fb1ae885bd5efaca0138787b5eb1b', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Organic sales', value=8510.0, unit='USD', scale_factor=1.0, period='Fiscal Years Ended', doc_section='Total Company', source_chunk_id='0dbf27f3-f0e1-4c5a-8a20-501138370fed', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='18ca1b0c6c1431fabb221e2426483d4b', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Acquisition sales', value=321.0, unit='USD', scale_factor=1.0, period='Fiscal Years Ended', doc_section='Total Company', source_chunk_id='0dbf27f3-f0e1-4c5a-8a20-501138370fed', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='76e4dc01af434ae8e0ebb6d5dd3d851f', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net sales', value=8831.0, unit='USD', scale_factor=1.0, period='Fiscal Years Ended', doc_section='Total Company', source_chunk_id='0dbf27f3-f0e1-4c5a-8a20-501138370fed', nuance_note=None, confidence=0.95, related_entity_id=None),
#  UFLRow(row_id='931d9581c4416e15b8ad17b1cc70d856', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Increase in Organic Sales', value=615000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='a6ddc782-e158-45cf-9027-bddf4262cdde', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='0f9c141a4623219910b7c3d78b3d3704', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Increase in Organic Sales', value=252000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='a6ddc782-e158-45cf-9027-bddf4262cdde', nuance_note='7.7%', confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='8cc8b5025e110b76ac3787ea203e027c', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Cost of Sales', value=352000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='a6ddc782-e158-45cf-9027-bddf4262cdde', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='dbbc6220fefa9cb28e1fc3066b94ff46', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Cost of Sales', value=326800000.0, unit='USD', scale_factor=1.0, period='2024', doc_section='Total Company', source_chunk_id='a6ddc782-e158-45cf-9027-bddf4262cdde', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='c466c2b82a467dec253ecd892a1b7fb2', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Percentage Increase in Cost of Sales', value=7.7, unit='Percent', scale_factor=1.0, period='2025', doc_section='Total Company', source_chunk_id='a6ddc782-e158-45cf-9027-bddf4262cdde', nuance_note=None, confidence=1.0, related_entity_id=None),
#  UFLRow(row_id='54f0bdc2f8cc7559ae232b946c1e0220', entity_id='ID_TDG', entity_name_raw='TransDigm Group Incorporated', metric_name='Net Sales', value=500000000.0, unit='USD', scale_factor=1.0, period='2025', doc_section='Business Segments', source_chunk_id='0adc8287-2fc7-411d-ab57-9e5e65da4965', nuance_note=None, confidence=1.0, related_entity_id=None)]
